# %%
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
counties = gpd.read_file('../data/county/tncounty.shp')

# %%
counties

# %%
tennessee = pd.read_csv('../data/tennessee.csv')

# %%
tennessee
# Out:
#          State      County  Year  Days with AQI  Good Days  Moderate Days  \
# 0    Tennessee    Anderson  2021            235        219             16
# 1    Tennessee      Blount  2021            365        292             71
# 2    Tennessee   Claiborne  2021            357        339             18
# 3    Tennessee    Davidson  2021            365        237            124
# 4    Tennessee      DeKalb  2021            363        349             14
# ..         ...         ...   ...            ...        ...            ...
# 182  Tennessee    Sullivan  2014            365        307             58
# 183  Tennessee      Sumner  2014            280        216             63
# 184  Tennessee       Union  2014            365        355             10
# 185  Tennessee  Williamson  2014            234        210             23
# 186  Tennessee      Wilson  2014            238        214             24
#
#      Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# ...

# %%
ten_2021 = tennessee.loc[tennessee['Year'] == 2021]

# %%
ten_2021
# Out:
#         State      County  Year  Days with AQI  Good Days  Moderate Days  \
# 0   Tennessee    Anderson  2021            235        219             16
# 1   Tennessee      Blount  2021            365        292             71
# 2   Tennessee   Claiborne  2021            357        339             18
# 3   Tennessee    Davidson  2021            365        237            124
# 4   Tennessee      DeKalb  2021            363        349             14
# 5   Tennessee        Dyer  2021            350        295             54
# 6   Tennessee    Hamilton  2021            351        258             92
# 7   Tennessee   Jefferson  2021            235        199             36
# 8   Tennessee        Knox  2021            365        239            121
# 9   Tennessee    Lawrence  2021            357        319             38
# 10  Tennessee      Loudon  2021            365        316             49
# 11  Tennessee     Madison  2021            356        298             57
# ...

# %%
ten_2021 = ten_2021[['County','Max AQI']].reset_index(drop=True)

# %%
ten_2021.columns = ['County', 'max_AQI_2021']

# %%
ten_2021
# Out:
#         County  max_AQI_2021
# 0     Anderson            87
# 1       Blount           107
# 2    Claiborne            71
# 3     Davidson           116
# 4       DeKalb            84
# 5         Dyer           105
# 6     Hamilton           101
# 7    Jefferson           100
# 8         Knox           150
# 9     Lawrence            97
# 10      Loudon            90
# 11     Madison           106
# 12       Maury           109
# 13      McMinn            89
# 14  Montgomery           138
# 15      Putnam            90
# 16       Roane            88
# 17      Sevier            93
# 18      Shelby           150
# 19    Sullivan           100
# 20      Sumner           133
# 21  Williamson            67
# 22      Wilson            74

# %%
ten_2020 = tennessee.loc[tennessee['Year'] == 2020]

# %%
ten_2020 = ten_2020[['County','Year','Max AQI']].reset_index(drop=True)

# %%
ten_2020
# Out:
#         County  Year  Max AQI
# 0     Anderson  2020       64
# 1       Blount  2020       92
# 2    Claiborne  2020       51
# 3     Davidson  2020      116
# 4       DeKalb  2020       61
# 5         Dyer  2020      117
# 6     Hamilton  2020      151
# 7    Jefferson  2020       74
# 8         Knox  2020       90
# 9     Lawrence  2020       72
# 10      Loudon  2020       97
# 11     Madison  2020      108
# 12       Maury  2020       91
# 13      McMinn  2020       88
# 14  Montgomery  2020      116
# 15      Putnam  2020      105
# 16       Roane  2020       91
# 17      Sevier  2020      105
# 18      Shelby  2020      152
# 19    Sullivan  2020       80
# 20      Sumner  2020      121
# 21  Williamson  2020       71
# 22      Wilson  2020       64

# %%
ten_2020 = ten_2020.drop(columns= ['Year'])

# %%
ten_2020.columns = ['County', 'max_AQI_2020']

# %%
ten_2020
# Out:
#         County  max_AQI_2020
# 0     Anderson            64
# 1       Blount            92
# 2    Claiborne            51
# 3     Davidson           116
# 4       DeKalb            61
# 5         Dyer           117
# 6     Hamilton           151
# 7    Jefferson            74
# 8         Knox            90
# 9     Lawrence            72
# 10      Loudon            97
# 11     Madison           108
# 12       Maury            91
# 13      McMinn            88
# 14  Montgomery           116
# 15      Putnam           105
# 16       Roane            91
# 17      Sevier           105
# 18      Shelby           152
# 19    Sullivan            80
# 20      Sumner           121
# 21  Williamson            71
# 22      Wilson            64

# %%
tennessee_compare = pd.merge(ten_2021, ten_2020 , on = 'County')

# %%
tennessee_compare
# Out:
#         County  max_AQI_2021  max_AQI_2020
# 0     Anderson            87            64
# 1       Blount           107            92
# 2    Claiborne            71            51
# 3     Davidson           116           116
# 4       DeKalb            84            61
# 5         Dyer           105           117
# 6     Hamilton           101           151
# 7    Jefferson           100            74
# 8         Knox           150            90
# 9     Lawrence            97            72
# 10      Loudon            90            97
# 11     Madison           106           108
# 12       Maury           109            91
# 13      McMinn            89            88
# 14  Montgomery           138           116
# 15      Putnam            90           105
# 16       Roane            88            91
# 17      Sevier            93           105
# 18      Shelby           150           152
# 19    Sullivan           100            80
# 20      Sumner           133           121
# ...

# %%
tennessee_compare.to_csv('tennessee_compare.csv',index=False)

# %%
ten_map = pd.merge(counties, ten, left_on ='NAME' , right_on ='County')

# %%
ten_map.to_csv('ten_map.csv', index=False)

# %%
counties.plot()

# %%
fig, ax = plt.subplots(figsize=(16,4))
ten_map.plot(column = 'Good Days', 
              ax = ax)
ax.axis('off');
