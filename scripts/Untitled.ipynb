# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
asthma_new = pd.read_csv('data/asthma_data_adults.csv')

# %%
asthma_new
# Out:
#              state asthma_total  asthma_perc
# 0          Alabama      394,199         10.1
# 1           Alaska       49,453          9.0
# 2          Arizona      519,749          9.4
# 3         Arkansas      207,857          9.0
# 4       California    2,694,396          8.8
# 5         Colorado      476,932         10.4
# 6      Connecticut      300,910         10.5
# 7         Delaware       77,695          9.8
# 8          Georgia      772,663          9.4
# 9           Hawaii       92,849          8.1
# 10           Idaho      138,516          9.8
# 11        Illinois      860,395          8.7
# 12         Indiana      536,397         10.3
# 13            Iowa      224,466          9.1
# 14          Kansas      235,953         10.6
# 15        Kentucky      408,801         11.7
# 16       Louisiana      344,842          9.7
# 17           Maine      138,396         12.5
# 18        Maryland      451,158          9.4
# 19   Massachusetts      661,306         11.7
# ...

# %%
asthma_new.asthma_perc = asthma_new.asthma_perc.apply(lambda x: str(x) + '%')

# %%
asthma_new
# Out:
#              state asthma_total asthma_perc
# 0          Alabama      394,199       10.1%
# 1           Alaska       49,453        9.0%
# 2          Arizona      519,749        9.4%
# 3         Arkansas      207,857        9.0%
# 4       California    2,694,396        8.8%
# 5         Colorado      476,932       10.4%
# 6      Connecticut      300,910       10.5%
# 7         Delaware       77,695        9.8%
# 8          Georgia      772,663        9.4%
# 9           Hawaii       92,849        8.1%
# 10           Idaho      138,516        9.8%
# 11        Illinois      860,395        8.7%
# 12         Indiana      536,397       10.3%
# 13            Iowa      224,466        9.1%
# 14          Kansas      235,953       10.6%
# 15        Kentucky      408,801       11.7%
# 16       Louisiana      344,842        9.7%
# 17           Maine      138,396       12.5%
# 18        Maryland      451,158        9.4%
# 19   Massachusetts      661,306       11.7%
# ...

# %%
asthma_new.to_csv('asthma_adults.csv', index=False)
